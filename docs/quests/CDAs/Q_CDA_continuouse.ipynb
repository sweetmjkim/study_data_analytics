# %% [markdown]
# <a href="https://colab.research.google.com/github/sweetmjkim/study_data_analytics/blob/main/docs/quests/CDAs/Q_CDA_continuouse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # X(연속형) / Y(연속형) 케이스

# %% [markdown]
# ## 문제 2번 : 판매된 수량(X)이 각 과일 유형의 단가(Y)와 어떤 관계가 있습니까?
# - 분석 방법: 수량과 가격 사이의 관계의 강도와 방향을 측정하기 위한 피어슨 또는 스피어만
# - 분석 내용 : 판매된 수량(X)이 각 과일 유형의 단가(Y)와 어떤 관계인가?
#  + 귀무가설 : 판매된 수량(X)이 각 과일 유형의 단가(Y)와 관계 없다.
#  + 대립가설 : 판매된 수량(X)이 각 과일 유형의 단가(Y)와 관계 있다.

# %% [markdown]
# ## 한글 폰트 설치

# %%
# 한글 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab 경우 Reuntime > Restart session 필요

# %% [markdown]
# ## matplotlib 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용

# %% [markdown]
# ## load dataset

# %%
import pandas as pd
df_fs =pd.read_csv('/content/fruitstore_saleshistory.csv')
df_fs[:3]
# Out:
#          공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류 물품중분류  물품소분류  \
# 0  2018-01-02  화    1     1   272369856  정상회원    과실    과일     사과
# 1  2018-01-02  화    1     1  1506656256  정상회원    채소    버섯  느타리버섯
# 2  2018-01-02  화    1     1  1506656256  정상회원   축산물     알    유정란
#
#                 물품명  구매수량 주소-구  주소-동 성별    연령    연령대     구매금액 구매매장  반품_원거래일자  \
# 0       사과/유(1.5kg)   1.0  수지구  풍덕천동  여  45.0    40대  22207.0  매장C       NaN
# 1       느타리버섯(300g)   1.0  수지구  풍덕천동  여  36.0  30대이하   4977.0  매장C       NaN
# 2  유정란/매장용(10알/국내산)   1.0  수지구  풍덕천동  여  36.0  30대이하   7083.0  매장C       NaN
#
#     구매시각
# 0  10:04
# 1  10:05
# 2  10:05

# %%
# 결측치 확인
df_fs[['구매수량', '구매금액', '물품중분류']].isnull().sum()
df_fs.dropna(subset=['물품중분류'] ,inplace=True)
df_fs['물품중분류']
# Out:
# 0              과일
# 1              버섯
# 2               알
# 3           두부/유부
# 4               빵
#            ...
# 47495    잼/병조림/기타
# 47496         밑반찬
# 47497        어묵/묵
# 47498           알
# 47499        식사대용
# Name: 물품중분류, Length: 47500, dtype: object

# %%
# 결측치 제거
df_fs[['구매수량', '구매금액', '물품중분류']].isnull().sum()
df_fs_amount = df_fs[['구매수량', '구매금액']].dropna()
df_fs_amount
# Out:
#        구매수량     구매금액
# 0       1.0  22207.0
# 1       1.0   4977.0
# 2       1.0   7083.0
# 3       1.0    766.0
# 4       1.0   4403.0
# ...     ...      ...
# 47495   1.0  12922.0
# 47496   5.0  22016.0
# 47497   1.0   7083.0
# 47498   2.0  14167.0
# 47499   1.0  17230.0
#
# [47500 rows x 2 columns]

# %%
# 물품중분류에서 과일 카테고리만 확인
df_fs_category_fruit = df_fs[df_fs['물품중분류'] == '과일']
df_fs_category_fruit[:3]
# Out:
#            공급일자 요일  공급월  공급주차       회원번호 조합원상태 물품대분류 물품중분류  물품소분류  \
# 0    2018-01-02  화    1     1  272369856  정상회원    과실    과일     사과
# 62   2018-01-02  화    1     1  445131904  정상회원    과실    과일    건대추
# 132  2018-01-02  화    1     1  744508416  정상회원    과실    과일  귤(조생)
#
#              물품명  구매수량 주소-구  주소-동 성별    연령  연령대     구매금액 구매매장  반품_원거래일자   구매시각
# 0    사과/유(1.5kg)   1.0  수지구  풍덕천동  여  45.0  40대  22207.0  매장C       NaN  10:04
# 62     건대추(500g)   1.0  수지구  풍덕천동  여  58.0  50대  22973.0  매장C       NaN  12:18
# 132   귤/유(1.5kg)   1.0  기흥구   보정동  여  63.0  60대  11104.0  매장C       NaN  14:58

# %%
df_fs_category_fruit[['구매수량', '구매금액']].count()
# Out:
# 구매수량    1553
# 구매금액    1553
# dtype: int64

# %%
# 연관 계수 확인
df_fs_amount.corr()
# Out:
#           구매수량      구매금액
# 구매수량  1.000000  0.254172
# 구매금액  0.254172  1.000000

# %%
import scipy.stats as stats
stats.pearsonr(df_fs_amount['구매수량'], df_fs_amount['구매금액'])
# Out:
# PearsonRResult(statistic=0.2541715612319635, pvalue=0.0)

# %% [markdown]
# ### 분석 결과
# - 통계 결론 :
# - 사실 결론 :
